# %% [markdown]
# Hello!
# My name is Ekaterina. I'm happy to review your project today.
# When I will see mistake at the first time, I will just point it out. I let you find it and fix it by
# yourself. I'm trying to prepare you to work as an Data Analyst. SO, at a real job, your team lead
# will do the same. But if you can't handle this task yet, I will give you a more accurate hint at the
# next iteration.
# You will find my comments below - please do not move, modify or delete them.
# You can find my comments in green, yellow or red boxes like this:
# <div class="alert alert-block alert-success"> <b>Reviewer's comment</b> <a
# class="tocSkip"></a>
# Success. Everything is done succesfully. </div>
# <div class="alert alert-block alert-warning"> <b>Reviewer's comment</b> <a
# class="tocSkip"></a>
# Remarks. Some recommendations. </div>
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
# Needs fixing. The block requires some corrections. Work can't be accepted with the red
# comments. </div>
# You can answer me by using this:
# <div class="alert alert-block alert-info"> <b>Student answer.</b> <a class="tocSkip"></a>
# </div>
#
#
# **Keep in mind that the project will be accepted only when all the “red” issues are resolved.**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>**General feedback**</b> <a class="tocSkip"></a>
#
# Thank you for submitting your project!
#
# <div class="alert alert-block alert-danger">
# <b>Please add the title and use plt.show()</b> <a class="tocSkip"></a>
# </div>
#
# </div>

# %% [markdown]
# <h1>Sprint8: Data Visualization with Python Project</h1>
#
# ---
#
# <h1>Project Description</h1>
#
# For Sprint 8's project, we are given a dataset and a graphical representation. The primary objective is to replicate the given graphical depiction using the supplied dataset wtih either the Seaborn or Plotly library.
#
# The dataset encompasses the outcomes of a simulated research study, wherein 100 red squirrels were subjected to one of three distinct dietary regimes post-weaning, and their final adult weights were meticulously documented.
# The graphical representation presented below encapsulates the findings of this investigation and serves as the benchmark for the replication task.
# The choice between Seaborn and Plotly is placed by my discretion.
# Upon completion, we are required to submit a Jupyter Notebook in .ipynb format, inclusive of your code implementation and the resultant figure it generates.
# To pass, the reviewer will execute my code and juxtapose my figure against the original.
#
# ![graph image](S8PROJECT_recreate-graph.png)
#
#
# <u><h3>The deliverables to replicate within the project:</h3></u>
#
# - Title and axis labels
# - Axis ticks and their respective ranges
# - Legend
# - Magenta and green data points (the color exactness is not obligatory)
# - Data grouping and presentation
# - Other attributes of the figure, such as font size, style, or image dimensions, may be tailored tomy preference.
# - Utilize official documentation or external references to address tasks not explicitly covered in this course section supplemented by additional resources as needed.
#
# Furthermore, there is a disclaimer stated within the project that there can be multiple valid solutions to this project. The code's specifics will depend on whether Seaborn or Plotly is opted for. And even within a single library, various methods may be employed to achieve the same outcome.
#
# > - project description is also available through README.md on my github repository where project and all necessary files are also uploaded: https://github.com/stxphz/Sprint8-Project

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Reviewer's comment</b> <a
# class="tocSkip"></a>
# Super introduction </div>

# %%
# adding necessary packages to run script and render plots

# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (23.2.1)

# %%
# adding necessary packages to run script and render plots

# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (5.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly) (23.1)

# %%
# adding necessary packages to run script and render plots

# !pip install plotly-express
# Out:
# Requirement already satisfied: plotly-express in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly-express) (2.0.3)
# Requirement already satisfied: plotly>=4.1.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly-express) (5.17.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly-express) (0.14.0)
# Requirement already satisfied: scipy>=0.18 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly-express) (1.10.1)
# Requirement already satisfied: patsy>=0.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly-express) (0.5.3)
# Requirement already satisfied: numpy>=1.11 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly-express) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas>=0.20.0->plotly-express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas>=0.20.0->plotly-express) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas>=0.20.0->plotly-express) (2023.3)
# Requirement already satisfied: six in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from patsy>=0.5->plotly-express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly>=4.1.0->plotly-express) (8.2.2)
# Requirement already satisfied: packaging in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from plotly>=4.1.0->plotly-express) (23.1)

# %%
# adding necessary packages to run script and render plots

# !pip install notebook
# Out:
# Requirement already satisfied: notebook in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (7.0.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from notebook) (2.7.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from notebook) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from notebook) (4.0.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from notebook) (6.3.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.7.1)
# Requirement already satisfied: argon2-cffi in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.6.0)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.0)
# Requirement already satisfied: overrides in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.3.1)
# Requirement already satisfied: packaging in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1)
# Requirement already satisfied: prometheus-client in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.0)
# Requirement already satisfied: pyzmq>=24 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: send2trash in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.0)
# Requirement already satisfied: websocket-client in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.6.1)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook) (2.0.4)
# Requirement already satisfied: ipykernel in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook) (6.25.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook) (2.2.0)
# Requirement already satisfied: tomli in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (4.19.1)
# Requirement already satisfied: requests>=2.31 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.1.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab<5,>=4.0.2->notebook) (4.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (6.0)
# Requirement already satisfied: rfc3339-validator in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.0.0)
# Requirement already satisfied: defusedxml in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.15.1)
# Requirement already satisfied: tinycss2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: fastjsonschema in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (2023.5.7)
# Requirement already satisfied: ptyprocess in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: appnope in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (8.16.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.5.6)
# Requirement already satisfied: psutil in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (5.9.5)
# Requirement already satisfied: six>=1.9.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: webencodings in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: backcall in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.0)
# Requirement already satisfied: decorator in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (3.0.38)
# Requirement already satisfied: stack-data in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (4.8.0)
# Requirement already satisfied: fqdn in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (2.4)
# Requirement already satisfied: uri-template in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.4.1)
# Requirement already satisfied: pycparser in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.6)
# Requirement already satisfied: arrow>=0.15.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (1.2.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.2)

# %%
# adding necessary packages to run script and render plots

# !pip install ipython
# Out:
# Requirement already satisfied: ipython in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (8.16.0)
# Requirement already satisfied: backcall in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (2.15.1)
# Requirement already satisfied: stack-data in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (5.9.0)
# Requirement already satisfied: exceptiongroup in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (1.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (4.8.0)
# Requirement already satisfied: appnope in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)

# %%
# adding necessary packages to run script and render plots

# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (6.25.2)
# Requirement already satisfied: appnope in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (8.16.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: packaging in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (23.1)
# Requirement already satisfied: psutil in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: backcall in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.15.1)
# Requirement already satisfied: stack-data in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: exceptiongroup in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (1.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)

# %%
# adding necessary packages to run script and render plots

# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (8.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipywidgets) (6.25.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipywidgets) (8.16.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipywidgets) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: appnope in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.1)
# Requirement already satisfied: psutil in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.2)
# Requirement already satisfied: backcall in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
# adding necessary packages to run script and render plots

# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# adding necessary packages to run script and render plots

# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/stephzeng/practicum/Sprint6-Project/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)

# %%
# read squirrel_diet.csv file and storing it to a variable 'df_squirrel' for DataFrame
import pandas as pd

try:
    df_squirrel = pd.read_csv('squirrel_diet.csv', sep=',')
    print('The right path is squirrel_diet.csv')
except:
    df_squirrel =  pd.read_csv('/datasets/squirrel_diet.csv', sep=',')
    print('The right path is /datasets/squirrel_diet.csv')

display(df_squirrel)
# Out:
# The right path is squirrel_diet.csv
#     sex  diet  weight
# 0     0     3   1.042
# 1     1     3   1.196
# 2     1     2   1.401
# 3     1     1   1.015
# 4     0     2   1.141
# ..  ...   ...     ...
# 95    0     1   0.995
# 96    1     2   1.979
# 97    0     3   1.099
# 98    0     2   1.327
# 99    1     1   0.990
#
# [100 rows x 3 columns]

# %% [markdown]
# <p>No data dictionary provided with dataset.</p>
#
# > Based on graph visualization given to recreate, the data on the graph calls for the sex as male or female. Diet A, B, or C. Weight of adult squirrel in lbs.
# > - assuming 0 is female and 1 is male
# > - assuming diet 1 is A, 2 is B, and 3 is C
# > - assuming float value in weight column is in lbs

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Reviewer's comment</b> <a
# class="tocSkip"></a>
# Great</div>

# %%
# obtain general information about data in squirrel_diet DataFrame including the index dtype and columns, non-null values and memory usage.

df_squirrel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     100 non-null    int64
#  1   diet    100 non-null    int64
#  2   weight  100 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 2.5 KB

# %% [markdown]
# - no missing values based on .info()

# %%
# validate there are no missing values

print((df_squirrel).isna().sum())
# Out:
# sex       0
# diet      0
# weight    0
# dtype: int64

# %%
# identify if there any duplicate values in squirrel_diet dataset

print(df_squirrel.duplicated())
print()
print(f"total duplicate values: {df_squirrel.duplicated().sum()}")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool
#
# total duplicate values: 0

# %%
# rename sex column name to sex_original
df_squirrel.rename(columns={'sex': 'sex_original'}, inplace=True)

display(df_squirrel)
# Out:
#     sex_original  diet  weight
# 0              0     3   1.042
# 1              1     3   1.196
# 2              1     2   1.401
# 3              1     1   1.015
# 4              0     2   1.141
# ..           ...   ...     ...
# 95             0     1   0.995
# 96             1     2   1.979
# 97             0     3   1.099
# 98             0     2   1.327
# 99             1     1   0.990
#
# [100 rows x 3 columns]

# %%
# duplicate sex column and rename column to 'sex'
df_squirrel['sex'] = df_squirrel['sex_original']

# rename 0 to male and 1 to female in column 'sex_M/F'
df_squirrel['sex'] = df_squirrel['sex'].replace({0: 'female', 1: 'male'})

display(df_squirrel)
# Out:
#     sex_original  diet  weight     sex
# 0              0     3   1.042  female
# 1              1     3   1.196    male
# 2              1     2   1.401    male
# 3              1     1   1.015    male
# 4              0     2   1.141  female
# ..           ...   ...     ...     ...
# 95             0     1   0.995  female
# 96             1     2   1.979    male
# 97             0     3   1.099  female
# 98             0     2   1.327  female
# 99             1     1   0.990    male
#
# [100 rows x 4 columns]

# %%
# duplicate diet column and renaming column to 'diet_A/B/C'
df_squirrel['diet_A/B/C'] = df_squirrel['diet']

# rename 1 to A, 2 to B, and 3 to C in column 'diet_A/B/C'
df_squirrel['diet_A/B/C'] = df_squirrel['diet_A/B/C'].replace({1: 'A', 2: 'B', 3: 'C'})

display(df_squirrel)
# Out:
#     sex_original  diet  weight     sex diet_A/B/C
# 0              0     3   1.042  female          C
# 1              1     3   1.196    male          C
# 2              1     2   1.401    male          B
# 3              1     1   1.015    male          A
# 4              0     2   1.141  female          B
# ..           ...   ...     ...     ...        ...
# 95             0     1   0.995  female          A
# 96             1     2   1.979    male          B
# 97             0     3   1.099  female          C
# 98             0     2   1.327  female          B
# 99             1     1   0.990    male          A
#
# [100 rows x 5 columns]

# %%
# sources used: 
# https://seaborn.pydata.org/generated/seaborn.color_palette.html
#

# %%
# recreate graph using Seaborn Library

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.color_palette(palette="husl")
colors=sns.color_palette(['magenta', 'green'])
sns.stripplot(x='diet_A/B/C', y='weight', hue='sex', data=df_squirrel, palette=colors, order = ['A','B','C'])
plt.xlabel('Diet Label')
plt.ylabel('Adult Weight / lbs')

# v2. -> added title to graph and use plt.show to display graph
plt.title('Red Squirrel Diet Study')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
# Please add the title and use plt.show to avoid displaying service information Text(0, 0.5, 'Adult Weight / lbs') </div>
